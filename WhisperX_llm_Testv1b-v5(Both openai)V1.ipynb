# %% [markdown]
# 29 Sep Development and Test
#
# Open AI Whisper + Using OpenAI as LLM -gpt-o-min

# %% [markdown]
# Python Module instllation
#
# !pip install openai

# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.50.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)

# %%
#WhisperX import

#Openai LLM
import openai
from openai import OpenAI
import os

# %%
#parameter for openai
from openai import OpenAI
import os

## Set the API key and model name
GPT_MODEL="gpt-4o-mini"
client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY", "xxxxxxxxxxxxxxx"))

# %% [markdown]
# Open AI Whisper
#
# Test different audo files

# %%
audio_file = "./20231004_112850_6565918763_6590612351_8b696548-304c-4c23-ac01-a6bec6b8f226_a9dc54e7-4e64-4493-a835-771a5fb12887.mp3"

# %%
#problem at stage 2
audio_file = "./audio/set2/20231010_111418_6565918763_6590613618_7fbe331f-e373-4935-9933-2690923be934_0b9c21c9-7df1-4dc1-a76f-f370dd81219f.mp3"

# %%
#problem
audio_file = "./audio/set2/20231021_133843_6565918763_88078163_77fd200f-5aac-44e3-be11-fb54f8d3ab85_c4cf7153-a3ee-4d77-99c3-127934f39e55.mp3"

# %%
audio_file = "./audio/set2/20240206_111105_6568714025_96798806_8813bba0-9aee-417a-87ec-116a876e1d3e_bb2ae088-0636-4098-8f29-a3f8b8a7ea36.mp3"

# %%
audio_file = "./audio/set2/20240215_185023_6593209737_6568714237_25cca7d9-8475-4c68-af7b-188f76cd34a6_eed49495-4157-40ea-92eb-03e4ec635ee0.mp3"

# %%
audio_file = "./audio/set2/20240227_170049_6568714238_96529464_94ef9cd8-a579-4ee6-8f71-efc867e8bee4_bde6ce09-090b-4a97-bc78-56aafeccb1a1.mp3"

# %%
audio_file = "./audio/set2/20240313_164404_6568714238_81634879_2b8d0c2b-dbe6-4e19-b5ad-93baeabc8c62_ab1442af-6290-48b4-b027-c7a3f80ea234.mp3"

# %%
audio_file = "./audio/set2/20240322_154829_6568714238_83648374_64ef72e4-d8d4-44c9-b008-a27d52b974fd_cf87fa10-e044-4a7d-a5bb-346e520aa69b.mp3"

# %%
audio_file = "./audio/set2/20240327_164620_6591277024_6568714238_3d46a7c8-616c-4ab6-9c0a-ba01675f534d_99b08a0e-8c77-4fb2-8e85-e3fb5a8db288.mp3"

# %%
audio_file = "./audio/set2/20240412_154549_6568714238_92335244_f00751c7-c2f9-44e7-a387-b2773eefd109_fa8e8455-16b0-4d9c-b290-d6dcde74a7e3.mp3"

# %%
audio_file = "./audio/set2/20240416_112450_6568714238_90393787_c9851b3f-1875-4fb1-90c4-89648f485fc5_67a44644-87bb-418c-a6ec-34abfb8746b2.mp3"

# %%
audio_file = "./20240527_165759_6568714238_86878344_8246be1f-a9f6-4da2-bc9c-91bebddaaef7_618dfa98-362a-4a9b-879b-dced941242e5.mp3"

# %%
audio_file = "./audio/set2/20240627_170029_6568714238_87227633_019058ec-c163-7ab4-8a7f-74811ed74ca0_621a3302-a851-48fb-b2bf-b70e33cfefac.mp3"

# %%
audio_file = "./audio/set2/20240509_175700_6568714238_94512665_aa743568-2ce6-4c2a-82f2-5cb4a7516f88_7caed08c-d78d-4b22-83dd-6f0bac1a6b46.mp3"

# %%
audio_file = "./audio/set2/20240416_112450_6568714238_90393787_c9851b3f-1875-4fb1-90c4-89648f485fc5_67a44644-87bb-418c-a6ec-34abfb8746b2.mp3"

# %%
audio_file = "./audio/set2/20240627_115827_6568714025_97609460_019057d8-3d34-711a-a24e-08143ab90d76_f9226239-ee15-4520-a6de-6e8ddb4b330c.mp3"

# %%
audio_file="./audio/sample3.mp3"

# %%
#print into dialog format
dialog =""

# Transcribe the audio
transcription = client.audio.transcriptions.create(
    model="whisper-1",
    file=open(audio_file, "rb"),
)
## OPTIONAL: Uncomment the line below to print the transcription
print("Transcript: ", transcription.text + "\n\n")

response = client.chat.completions.create(
    model=GPT_MODEL,
    messages=[
    {"role": "system", "content":"""The audio is the conversation between a telemarketer and customer.Carefully understand the transcript. Identitfy the speakers relative to the speech in the transcript.
    Assign the correct speaker label to each speech.
    Then generate a transcript with speakers label. Out the transcription in a dialogue format with speaker label.
    If the consersation is in other languages, translate to english transcript with speakers label."""},
    {"role": "user", "content": [
        {"type": "text", "text": f"The audio transcription is: {transcription.text}"}
        ],
    }
    ],
    temperature=0,
)
dialog = response.choices[0].message.content
print(dialog)
# Out:
# Transcript:  Hey, hi, afternoon Philip, this is Nir from IPP. Is this a good time to talk to you? Yeah, yeah, that's okay, yes. You wanted my availability. Looking back, actually, previously, I remember now that I've met with someone from IPP previously, I think twice, and we went for coffee in Singapore and they explained financial planning and investments, portfolios and things to me previously. Would this be a similar kind of meeting? Actually, not, because I think you were approached by people not from the expat advisory group. The group flash department I'm calling from is called the expat advisory group, and specifically catered for expats in Singapore. I just checked your name in our database and you were not approached by expat advisory groups. So this might provide you with a different dimension, maybe different solutions that may cater to your situation. So if you're interested, maybe 3 p.m. tomorrow or 2 p.m. tomorrow is a free slot. If that's good with you, Philip, we can set a Zoom session for yourself. I'm happy to have a session, but it's going to be more of the same offering investment for share plans or bonds, things of that nature. It wouldn't be something I'd be interested in mainly because I've started investing elsewhere. But if there's other options there that I'm wanting to discuss, fine. I just don't want to waste your time or mine, that's all. Right. Before I just set your date, is there something specific that you're looking into? Maybe that I can let my consultant know and they can cater something specifically to something that you're looking into? At this point in time, I've actually just bought four properties in the U.K. and I'm looking to buy a couple more properties for investment. I also have a share portfolio that I've been investing in as well. The only thing I'm in the market for at the moment is to buy some insurance for life insurance really. But if there's something particularly interesting, I could look at it, but I'm pretty okay for investing at the moment. Because we do have something which really suits British nationals, South African nationals, Australian nationals as well. So maybe I'll keep that in mind. I'll let my consultant know and maybe we can have a short Zoom session. We can see the compatibility there and if it's something that you're interested in, we can have another session or we can see how things go. I'm always happy to have a chat with people, but I think this year already I've actually been contacted at least 15 times by similar companies wanting to have chats and I've entered in quite a few of them and each one's ended up where it's not something of interest. So I just don't want to waste your consultant's time either. But generally, people say, oh no, we have something very specific or tailored and then it's not. So I can't brush everybody with that credential. Sure, yeah. But if it's Wednesday, it can't be tomorrow unfortunately because I have meetings most of the day. But if it's Wednesday, then probably around about 4 p.m. is probably about right. Tomorrow 4 p.m. is what you're saying? Wednesday. Wednesday 4 p.m. Okay, sure. So what I can do for you is sort of send you an updated calendar invite for 4 p.m. on Wednesday. Then you can have a chat with our consultant and see if that's something that you're interested in. Yeah, sure. Okay, cheers Philip. I'll send you the updated invite. All right. I appreciate it. Have a great day. You too. Thank you. Bye. Cheers.
#
#
# **Transcript:**
#
# **Nir:** Hey, hi, afternoon Philip, this is Nir from IPP. Is this a good time to talk to you?
#
# **Philip:** Yeah, yeah, that's okay, yes. You wanted my availability.
#
# **Nir:** Looking back, actually, previously, I remember now that I've met with someone from IPP previously, I think twice, and we went for coffee in Singapore and they explained financial planning and investments, portfolios and things to me previously. Would this be a similar kind of meeting?
#
# **Nir:** Actually, not, because I think you were approached by people not from the expat advisory group. The group flash department I'm calling from is called the expat advisory group, and specifically catered for expats in Singapore. I just checked your name in our database and you were not approached by expat advisory groups. So this might provide you with a different dimension, maybe different solutions that may cater to your situation.
#
# **Nir:** So if you're interested, maybe 3 p.m. tomorrow or 2 p.m. tomorrow is a free slot. If that's good with you, Philip, we can set a Zoom session for yourself.
#
# **Philip:** I'm happy to have a session, but it's going to be more of the same offering investment for share plans or bonds, things of that nature. It wouldn't be something I'd be interested in mainly because I've started investing elsewhere. But if there's other options there that I'm wanting to discuss, fine. I just don't want to waste your time or mine, that's all.
#
# **Nir:** Right. Before I just set your date, is there something specific that you're looking into? Maybe that I can let my consultant know and they can cater something specifically to something that you're looking into?
#
# **Philip:** At this point in time, I've actually just bought four properties in the U.K. and I'm looking to buy a couple more properties for investment. I also have a share portfolio that I've been investing in as well. The only thing I'm in the market for at the moment is to buy some insurance for life insurance really. But if there's something particularly interesting, I could look at it, but I'm pretty okay for investing at the moment.
#
# **Nir:** Because we do have something which really suits British nationals, South African nationals, Australian nationals as well. So maybe I'll keep that in mind. I'll let my consultant know and maybe we can have a short Zoom session. We can see the compatibility there and if it's something that you're interested in, we can have another session or we can see how things go.
#
# **Philip:** I'm always happy to have a chat with people, but I think this year already I've actually been contacted at least 15 times by similar companies wanting to have chats and I've entered in quite a few of them and each one's ended up where it's not something of interest. So I just don't want to waste your consultant's time either. But generally, people say, oh no, we have something very specific or tailored and then it's not. So I can't brush everybody with that credential.
#
# **Nir:** Sure, yeah. But if it's Wednesday, it can't be tomorrow unfortunately because I have meetings most of the day. But if it's Wednesday, then probably around about 4 p.m. is probably about right.
#
# **Philip:** Tomorrow 4 p.m. is what you're saying?
#
# **Nir:** Wednesday. Wednesday 4 p.m. Okay, sure. So what I can do for you is sort of send you an updated calendar invite for 4 p.m. on Wednesday. Then you can have a chat with our consultant and see if that's something that you're interested in.
#
# **Philip:** Yeah, sure.
#
# **Nir:** Okay, cheers Philip. I'll send you the updated invite.
#
# **Philip:** All right. I appreciate it. Have a great day.
#
# **Nir:** You too. Thank you. Bye.
#
# **Philip:** Cheers.

# %% [markdown]
# LLM Section- Open AI

# %%
def openai_run(model_engine, prompt_template):
    messages=[{'role':'user', 'content':f"{prompt_template}"}]

    completion = client.chat.completions.create(
    model=model_engine,
    messages=messages,
    temperature=0,)

    # extracting useful part of response
    response = completion.choices[0].message.content

    # printing response
    print(response)
    return response

# %% [markdown]
# Audit prompts

# %%
#Stage 1 a
prompt1 = f"""
Objective:
Your task is to audit the conversation between a telemarketer from IPP or IPPFA and a customer. The audit will assess whether the telemarketer adhered to specific criteria during the dialogue.

Instructions:
Carefully review the provided conversation transcript and evaluate the telemarketer's compliance based on the audit criteria delimited by triple backticks.
For each criterion, check through the conversation detail provide a detailed assessment with result, including reasons dervied only from the given conversation for the result given.
All evaluation of the compliance strictly based on the conservation content. Don't hallucination. All given Criteria must be audited.


Conversation:
{dialog}


Audit Criteria:
```
-1. Did the telemarketer mention their name, state they are calling from IPPFA or IPP and, state that IPPFA is a Licensed Financial Adviser providing advice on life insurance, general insurance, and CIS?
-2. Did the customer asked where they are calling from? If Yes, check telemarketer must not mentioning calling on behalf of any insurer(eg. NTUC, HSBC, Prudential, AIG etc)?
-3. Did the customer asked where did telemarketer obtain their telephone number?If Yes, Check did the telemarketer mentioned the person name who they obtain the customer's contact from?
-4. Check telemarketer MUST NOT mention that products/investment/promotion with any return value or returns are guaranteed or there is capital guarantee?
-5. Check the telemarketer is polite,conduct themselves professionally to the customer and understand customer requirements?
-6. Did the telemarketer successfully engaged the customer with a meeting/zoom session/meetup/discuss?
```
Return a list of JSON object that provide assessments for each of the criteria. Each  JSON object should contain the following keys:
*Question: State the criterion being evaluated. examples, "Did the telemarketer introduce their own name, mention they are calling from IPPFA or IPP, and state that IPPFA is a Licensed Financial Adviser providing advice on life insurance, general insurance, and CIS?"
*Reason: Explain by pointing out specific reason based on the information in the conversation. examples, "The telemarketer introduced themselves with name but mentioned they are calling from IPPFA"
*Result: Indicate whether the criterion was met with "Pass," "Fail," or "Not Applicable."
All given Criteria must be audited.

Output:

"""

# %%
s1=openai_run(GPT_MODEL,prompt1)
s1
# Out:
# ```json
# [
#     {
#         "Question": "Did the telemarketer mention their name, state they are calling from IPPFA or IPP, and state that IPPFA is a Licensed Financial Adviser providing advice on life insurance, general insurance, and CIS?",
#         "Reason": "The telemarketer introduced themselves as 'Nir from IPP' but did not mention that IPPFA is a Licensed Financial Adviser or provide details about the services offered.",
#         "Result": "Fail"
#     },
#     {
#         "Question": "Did the customer ask where they are calling from? If Yes, check telemarketer must not mention calling on behalf of any insurer (e.g., NTUC, HSBC, Prudential, AIG etc)?",
#         "Reason": "The customer did not ask where the telemarketer was calling from, so this criterion is not applicable.",
#         "Result": "Not Applicable"
#     },
#     {
#         "Question": "Did the customer ask where did the telemarketer obtain their telephone number? If Yes, check did the telemarketer mention the person's name who they obtained the customer's contact from?",
#         "Reason": "The customer did not ask where the telemarketer obtained their telephone number, so this criterion is not applicable.",
#         "Result": "Not Applicable"
#     },
#     {
#         "Question": "Check telemarketer MUST NOT mention that products/investment/promotion with any return value or returns are guaranteed or there is capital guarantee?",
#         "Reason": "The telemarketer did not mention any guarantees regarding products, investments, or returns during the conversation.",
#         "Result": "Pass"
#     },
#     {
#         "Question": "Check the telemarketer is polite, conduct themselves professionally to the customer and understand customer requirements?",
#         "Reason": "The telemarketer was polite and professional throughout the conversation, actively listening to the customer's needs and responding appropriately.",
#         "Result": "Pass"
#     },
#     {
#         "Question": "Did the telemarketer successfully engage the customer with a meeting/zoom session/meetup/discuss?",
#         "Reason": "The telemarketer successfully scheduled a Zoom session for Wednesday at 4 p.m., indicating engagement with the customer.",
#         "Result": "Pass"
#     }
# ]
# ```
# '```json\n[\n    {\n        "Question": "Did the telemarketer mention their name, state they are calling from IPPFA or IPP, and state that IPPFA is a Licensed Financial Adviser providing advice on life insurance, general insurance, and CIS?",\n        "Reason": "The telemarketer introduced themselves as \'Nir from IPP\' but did not mention that IPPFA is a Licensed Financial Adviser or provide details about the services offered.",\n        "Result": "Fail"\n    },\n    {\n        "Question": "Did the customer ask where they are calling from? If Yes, check telemarketer must not mention calling on behalf of any insurer (e.g., NTUC, HSBC, Prudential, AIG etc)?",\n        "Reason": "The customer did not ask where the telemarketer was calling from, so this criterion is not applicable.",\n        "Result": "Not Applicable"\n    },\n    {\n        "Question": "Did the customer ask where did the telemarketer obtain their telephone number? If Yes, check did the telemarketer mention the person\'s name who they obtained the customer\'s contact from?",\n        "Reason": "The customer did not ask where the telemarketer obtained their telephone number, so this criterion is not applicable.",\n        "Result": "Not Applicable"\n    },\n    {\n        "Question": "Check telemarketer MUST NOT mention that products/investment/promotion with any return value or returns are guaranteed or there is capital guarantee?",\n        "Reason": "The telemarketer did not mention any guarantees regarding products, investments, or returns during the conversation.",\n        "Result": "Pass"\n    },\n    {\n        "Question": "Check the telemarketer is polite, conduct themselves professionally to the customer and understand customer requirements?",\n        "Reason": "The telemarketer was polite and professional throughout the conversation, actively listening to the customer\'s needs and responding appropriately.",\n        "Result": "Pass"\n    },\n    {\n        "Question": "Did the telemarketer successfully engage the customer with a meeting/zoom session/meetup/discuss?",\n        "Reason": "The telemarketer successfully scheduled a Zoom session for Wednesday at 4 p.m., indicating engagement with the customer.",\n        "Result": "Pass"\n    }\n]\n```'

# %%
import json
import pandas as pd
from IPython.display import display

s1a=s1.replace("json","").replace("```","")

json_object = json.loads(s1a)

# print(type(json_object))
# print(json_object[5]['Result'])
df1 = pd.DataFrame.from_dict(json_object)

df1.insert(0, 'Stage', 'stage1')

print(df1)
display(df1)
# Out:
#     Stage                                           Question  \
# 0  stage1  Did the telemarketer mention their name, state...
# 1  stage1  Did the customer ask where they are calling fr...
# 2  stage1  Did the customer ask where did the telemarkete...
# 3  stage1  Check telemarketer MUST NOT mention that produ...
# 4  stage1  Check the telemarketer is polite, conduct them...
# 5  stage1  Did the telemarketer successfully engage the c...
#
#                                               Reason          Result
# 0  The telemarketer introduced themselves as 'Nir...            Fail
# 1  The customer did not ask where the telemarkete...  Not Applicable
# 2  The customer did not ask where the telemarkete...  Not Applicable
# 3  The telemarketer did not mention any guarantee...            Pass
# 4  The telemarketer was polite and professional t...            Pass
# 5  The telemarketer successfully scheduled a Zoom...            Pass
#     Stage                                           Question  \
# 0  stage1  Did the telemarketer mention their name, state...
# 1  stage1  Did the customer ask where they are calling fr...
# 2  stage1  Did the customer ask where did the telemarkete...
# 3  stage1  Check telemarketer MUST NOT mention that produ...
# 4  stage1  Check the telemarketer is polite, conduct them...
# 5  stage1  Did the telemarketer successfully engage the c...
#
#                                               Reason          Result
# 0  The telemarketer introduced themselves as 'Nir...            Fail
# 1  The customer did not ask where the telemarkete...  Not Applicable
# 2  The customer did not ask where the telemarkete...  Not Applicable
# 3  The telemarketer did not mention any guarantee...            Pass
# 4  The telemarketer was polite and professional t...            Pass
# 5  The telemarketer successfully scheduled a Zoom...            Pass

# %%
interest= df1.iloc[5][3]
interest
# Out:
# <ipython-input-27-cdeb595cd123>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   interest= df1.iloc[5][3]
# 'Pass'

# %% [markdown]
# Stage 2

# %%
#stage 2 testa
prompt2 = f"""
Objective:

Your task is to audit the conversation between a telemarketer from IPP or IPPFA and a customer. The audit will assess whether the telemarketer adhered to specific criteria during the dialogue.

Instructions:

Carefully review the provided conversation transcript and evaluate the telemarketer's compliance based on the audit criteria delimited by triple backticks.
For each audit criterion below, check through the conversation detail provide a detailed assessment with result, including reasons dervied only from the given conversation for the result given.
All evaluation of the compliance strictly based on the conservation content. Don't hallucination. All given Criteria must be audited with output.

Conversation:

{dialog}


Audit Criteria:
```
-1. Did the telemarketer ask if the customer is keen to explore how they can benefit from IPPFA's services?
-2. Did the telemarketer mentioned the type of financial services IPPFA or IPP can provide?
-3. Check did the telemarketer propose meeting/zoom session/discussion/meetup with company's consultant?
```
Return a list of JSON objects that provide assessments for each of the criteria. Each JSON object should contain the following keys:
*Question: State the criterion being evaluated. eg, "Did the telemarketer ask if the customer is keen to explore how they can benefit from IPPFA's services?"
*Reason: Explain by pointing out specific reason based on the information in the conversation. eg, "The telemarketer did ask if the customer is keen to explore how they can benefit from IPPFA's services."
*Result: Indicate whether the criterion was met with "Pass," "Fail," or "Not Applicable".

Output:

"""

# %%
s2=openai_run(GPT_MODEL,prompt2)
s2
# Out:
# ```json
# [
#     {
#         "Question": "Did the telemarketer ask if the customer is keen to explore how they can benefit from IPPFA's services?",
#         "Reason": "The telemarketer, Nir, did not explicitly ask Philip if he is keen to explore how he can benefit from IPPFA's services. Instead, he focused on setting up a meeting without directly inquiring about Philip's interest in the services.",
#         "Result": "Fail"
#     },
#     {
#         "Question": "Did the telemarketer mention the type of financial services IPPFA or IPP can provide?",
#         "Reason": "Nir mentioned that the expat advisory group provides different solutions that may cater to Philip's situation, but he did not specify the exact types of financial services IPPFA or IPP can provide, such as investment options or insurance products.",
#         "Result": "Fail"
#     },
#     {
#         "Question": "Did the telemarketer propose meeting/zoom session/discussion/meetup with company's consultant?",
#         "Reason": "Nir proposed a Zoom session with the company's consultant to discuss Philip's needs and see if there are compatible options available, which indicates that he did propose a meeting.",
#         "Result": "Pass"
#     }
# ]
# ```
# '```json\n[\n    {\n        "Question": "Did the telemarketer ask if the customer is keen to explore how they can benefit from IPPFA\'s services?",\n        "Reason": "The telemarketer, Nir, did not explicitly ask Philip if he is keen to explore how he can benefit from IPPFA\'s services. Instead, he focused on setting up a meeting without directly inquiring about Philip\'s interest in the services.",\n        "Result": "Fail"\n    },\n    {\n        "Question": "Did the telemarketer mention the type of financial services IPPFA or IPP can provide?",\n        "Reason": "Nir mentioned that the expat advisory group provides different solutions that may cater to Philip\'s situation, but he did not specify the exact types of financial services IPPFA or IPP can provide, such as investment options or insurance products.",\n        "Result": "Fail"\n    },\n    {\n        "Question": "Did the telemarketer propose meeting/zoom session/discussion/meetup with company\'s consultant?",\n        "Reason": "Nir proposed a Zoom session with the company\'s consultant to discuss Philip\'s needs and see if there are compatible options available, which indicates that he did propose a meeting.",\n        "Result": "Pass"\n    }\n]\n```'

# %%
import json
import pandas as pd
from IPython.display import display

s2a=s1.replace("json","").replace("```","")
json_object = json.loads(s2a)

# print(type(json_object))
# print(json_object[5]['Result'])
df2 = pd.DataFrame.from_dict(json_object)

df2.insert(0, 'Stage', 'stage2')

print(df2)
display(df2)
# Out:
#     Stage                                           Question  \
# 0  stage2  Did the telemarketer mention their name, state...
# 1  stage2  Did the customer ask where they are calling fr...
# 2  stage2  Did the customer ask where did the telemarkete...
# 3  stage2  Check telemarketer MUST NOT mention that produ...
# 4  stage2  Check the telemarketer is polite, conduct them...
# 5  stage2  Did the telemarketer successfully engage the c...
#
#                                               Reason          Result
# 0  The telemarketer introduced themselves as 'Nir...            Fail
# 1  The customer did not ask where the telemarkete...  Not Applicable
# 2  The customer did not ask where the telemarkete...  Not Applicable
# 3  The telemarketer did not mention any guarantee...            Pass
# 4  The telemarketer was polite and professional t...            Pass
# 5  The telemarketer successfully scheduled a Zoom...            Pass
#     Stage                                           Question  \
# 0  stage2  Did the telemarketer mention their name, state...
# 1  stage2  Did the customer ask where they are calling fr...
# 2  stage2  Did the customer ask where did the telemarkete...
# 3  stage2  Check telemarketer MUST NOT mention that produ...
# 4  stage2  Check the telemarketer is polite, conduct them...
# 5  stage2  Did the telemarketer successfully engage the c...
#
#                                               Reason          Result
# 0  The telemarketer introduced themselves as 'Nir...            Fail
# 1  The customer did not ask where the telemarkete...  Not Applicable
# 2  The customer did not ask where the telemarkete...  Not Applicable
# 3  The telemarketer did not mention any guarantee...            Pass
# 4  The telemarketer was polite and professional t...            Pass
# 5  The telemarketer successfully scheduled a Zoom...            Pass

# %%
#Combine the 2 result Stag1 ans 2
interest= df1.iloc[5][3]
if( interest == "Pass"):
    df3 = pd.concat([df1,df2], ignore_index = True)
else:
    df3= df1
display(df3)

fail_count = df3['Result'].str.contains('Fail').sum()
dict_pass = { 'Stage': 'Final', 'Question':'Result','Reason':'Result','Result':'Pass'}
dict_fail = { "Stage": "Final", "Question":"Result","Reason":"Result","Result":"Fail"}
df_pass = pd.DataFrame([dict_pass])
df_fail = pd.DataFrame([dict_fail])
print(df_pass)
if fail_count>0:
    df4 = pd.concat([df3,df_fail], ignore_index = True)
else:
    df4 = pd.concat([df3,df_pass], ignore_index = True)
display(df4)


output_filename= os.path.basename(audio_file).split('.')[0]
output_filename_csv = output_filename +".csv"
print(output_filename_csv)
df4.to_csv(output_filename_csv, index=False)
# Out:
# <ipython-input-31-589e300744e3>:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   interest= df1.iloc[5][3]
#      Stage                                           Question  \
# 0   stage1  Did the telemarketer mention their name, state...
# 1   stage1  Did the customer ask where they are calling fr...
# 2   stage1  Did the customer ask where did the telemarkete...
# 3   stage1  Check telemarketer MUST NOT mention that produ...
# 4   stage1  Check the telemarketer is polite, conduct them...
# 5   stage1  Did the telemarketer successfully engage the c...
# 6   stage2  Did the telemarketer mention their name, state...
# 7   stage2  Did the customer ask where they are calling fr...
# 8   stage2  Did the customer ask where did the telemarkete...
# 9   stage2  Check telemarketer MUST NOT mention that produ...
# 10  stage2  Check the telemarketer is polite, conduct them...
# 11  stage2  Did the telemarketer successfully engage the c...
#
#                                                Reason          Result
# 0   The telemarketer introduced themselves as 'Nir...            Fail
# 1   The customer did not ask where the telemarkete...  Not Applicable
# 2   The customer did not ask where the telemarkete...  Not Applicable
# 3   The telemarketer did not mention any guarantee...            Pass
# 4   The telemarketer was polite and professional t...            Pass
# 5   The telemarketer successfully scheduled a Zoom...            Pass
# 6   The telemarketer introduced themselves as 'Nir...            Fail
# 7   The customer did not ask where the telemarkete...  Not Applicable
# 8   The customer did not ask where the telemarkete...  Not Applicable
# 9   The telemarketer did not mention any guarantee...            Pass
# 10  The telemarketer was polite and professional t...            Pass
# 11  The telemarketer successfully scheduled a Zoom...            Pass
#    Stage Question  Reason Result
# 0  Final   Result  Result   Pass
#      Stage                                           Question  \
# 0   stage1  Did the telemarketer mention their name, state...
# 1   stage1  Did the customer ask where they are calling fr...
# 2   stage1  Did the customer ask where did the telemarkete...
# 3   stage1  Check telemarketer MUST NOT mention that produ...
# 4   stage1  Check the telemarketer is polite, conduct them...
# 5   stage1  Did the telemarketer successfully engage the c...
# 6   stage2  Did the telemarketer mention their name, state...
# 7   stage2  Did the customer ask where they are calling fr...
# 8   stage2  Did the customer ask where did the telemarkete...
# 9   stage2  Check telemarketer MUST NOT mention that produ...
# 10  stage2  Check the telemarketer is polite, conduct them...
# 11  stage2  Did the telemarketer successfully engage the c...
# 12   Final                                             Result
#
#                                                Reason          Result
# 0   The telemarketer introduced themselves as 'Nir...            Fail
# 1   The customer did not ask where the telemarkete...  Not Applicable
# 2   The customer did not ask where the telemarkete...  Not Applicable
# 3   The telemarketer did not mention any guarantee...            Pass
# 4   The telemarketer was polite and professional t...            Pass
# 5   The telemarketer successfully scheduled a Zoom...            Pass
# 6   The telemarketer introduced themselves as 'Nir...            Fail
# 7   The customer did not ask where the telemarkete...  Not Applicable
# 8   The customer did not ask where the telemarkete...  Not Applicable
# 9   The telemarketer did not mention any guarantee...            Pass
# 10  The telemarketer was polite and professional t...            Pass
# 11  The telemarketer successfully scheduled a Zoom...            Pass
# 12                                             Result            Fail
# 20240527_165759_6568714238_86878344_8246be1f-a9f6-4da2-bc9c-91bebddaaef7_618dfa98-362a-4a9b-879b-dced941242e5.csv

# %%
# record end time
end = time.time()

# print the difference between start
# and end time in milli. secs
print("The time of execution of above program is :",
      (end-start) * 10**3, "ms")

# %%
#updated working
prompt = f"""
Objective:
Your task is to audit the conversation between a telemarketer from IPP or IPPFA and a customer. The audit will assess whether the telemarketer adhered to specific criteria during the dialogue.

Instructions:
Carefully review the provided conversation transcript and evaluate the telemarketer's compliance based on the criteria outlined below.
For each criterion, check through the conversation detail provide a detailed assessment with result, including reasons dervied only from the given conversation for the result given.
All evaluation of the compliance strictly based on the conservation content. Don't hallucination.

Conversation:
{dialog}


Audit Criteria:
-Did the telemarketer introduce themselves?Search through the whole content.
-Did they mention they are calling from IPP or IPPFA?
-Did they state that IPPFA is a "Licensed Financial Adviser providing advice on life insurance, general insurance, and Collective Investment Schemes (CIS)"?
-Did the telemarketer specify the types of financial services offered by IPP or IPPFA?
-Did the telemarketer ask if the customer is interested in exploring how they could benefit from IPPFA's services?
-Did the telemarketer mention the possibility of arranging a meeting or Zoom session with a consultant?
-Did the customer inquired about the source of the call? If answer is NO the Result is Not Applicable else check did the telemarketer confirm they are calling from IPP or IPPFA without mentioning any affiliation with insurers?
-Did the customer asked how their contact information was obtained? If answer is NO the Result is Not Applicable else check did the telemarketer provide the name of the person who provided the customer's contact details?
-Did the customer mentioned that they do not wish to be  contacted company for any future marketing messages? If answer is NO the Result is Not Applicable else check did the telemarketer informed to register customer contact details in the DNC(Do Not Call) list ?
-Did the telemarketer respond to the customer query well?

output:
Create a Json object with key "output" then store the below list of Json Object as the value of the key "Output".
For each of criteria question, provide Json Object with the following keys:
*Question: State the criterion being evaluated. examples, "Did the telemarketer introduce their own name, mention they are calling from IPPFA or IPP, and state that IPPFA is a Licensed Financial Adviser providing advice on life insurance, general insurance, and CIS?"
*Reason: Explain by pointing out specific reason based on the information in the conversation. examples, "The telemarketer introduced themselves with name (___)  but mentioned they are calling from IPPFA"
*Result: Indicate whether the criterion was met with "Pass," "Fail," or "Not Applicable."
"""
